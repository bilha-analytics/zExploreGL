# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#The-Data" data-toc-modified-id="The-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>The Data</a></span></li><li><span><a href="#Assessment-Numbers" data-toc-modified-id="Assessment-Numbers-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Assessment Numbers</a></span></li></ul></div>

# %% [markdown]
# # Introduction
#
# - Types of cases
# - Timing of cases
# - CHV activity
# - Cases by location
# - CHV activity by location

# %% [markdown]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # The Data

# %%
# %run "C:\Users\BILHA\Google Drive\xRepos\xUtilz\\utilz_only_loader.ipynb"

# %%
db = pd.read_csv( r"C:\Users\BILHA\Box Sync\Analytics\Data Dumps\May-31\assessments.csv" )
#db.head()
db.dtypes
# Out:
#                                    uuid                                   chw  \
# 0  8974a22d-36ef-40c3-8798-ce5312563e8c  a970d423-a8d2-460a-86b8-ea092f9d465f
# 1  538247df-2827-4171-b6ab-96e4aec436bb  815e3451-6ef4-4c84-8731-c0bbfe69bfa3
# 2  07C7D0B5-2710-E7EA-92D4-091250C7FA53  cc7f40ce-fcdc-4469-a165-551c527c5d68
# 3  B4D1FCB4-61C4-207F-ACDB-ECA9DFB76888  59a3d58c-8875-4b11-a2e1-784befb328f4
# 4  8518F4F4-3575-4CC5-98C7-BBFFF20B6340  5b1c0410-532a-4473-b8f2-f45f6ff72540
#
#                  reported                            patient_id  \
# 0  2018-05-30 04:47:46+00  7cebbef1-5b6c-410b-a28b-c520e0a916f4
# 1  2018-05-13 16:01:36+00  EAEFB5C8-7398-B7B7-97A4-1973F190ED8E
# 2  2018-02-09 09:39:47+00  89088b99-337f-480d-8056-d56fe4d7defc
# 3  2017-03-22 15:35:41+00  685E61D4-CFD7-20EC-9CFD-93B2E5056D61
# 4  2017-03-22 15:13:26+00  DC2AA763-AD51-535D-8CA3-D001AF5E7E14
#
#   patient_date_of_birth  patient_age_in_years  patient_age_in_months  \
# 0            2002-05-30                    16                    192
# 1            2014-05-02                     4                     48
# 2            2017-01-27                     1                     12
# 3            1982-12-17                    34                    411
# 4            2012-03-07                     5                     60
#
#   patient_coughs patient_diarrhea patient_fever  \
# 0             no               no           yes
# 1             no               no           yes
# 2             no               no           yes
# 3             no               no           yes
# 4             no               no           yes
#
#                    ...                  treatment_follow_up  \
# 0                  ...                                 True
# 1                  ...                                 True
# 2                  ...                                 True
# 3                  ...                                 True
# 4                  ...                                False
#
#   referral_follow_up treat_for_malaria       lat        lng  \
# 0              False              True       NaN        NaN
# 1              False             False       NaN        NaN
# 2              False              True       NaN        NaN
# 3              False              True  0.515272  34.792253
# 4              False             False       NaN        NaN
#
#                         branch_uuid  branch_name  \
# 0  fc675f8ba170bc9692b3b706613a2e54       Malaba
# 1  fc675f8ba170bc9692b3b706613a2e54       Malaba
# 2  3096fd4c71868b066eb3710462230d06     Shinyalu
# 3  18ba22fb07334baa30fe0e81f9d7e2fc       Malava
# 4  a520223ea9bd16a37306513a4ff1b98e       Butula
#
#                         supervisor_uuid                         chw_area_uuid  \
# 0  ef1b5dec-5921-4ab0-871e-9b828b6df4f1  8d772d9f-e402-4d77-9eae-2ca6708a53b7
# 1  4ffdb8ad-0977-43b6-9425-6e72bc62f864  0288b61b-8700-4eb7-b37f-26ca2c2898f9
# 2  a53d03c9-af1b-411e-8432-aee8f94e8471  0afebe17-87a6-42c7-97df-f6cbc771fa00
# 3  d656c815-17d7-4f94-988d-f20177627deb  32fedad7-516c-45ec-b017-7c1a4f105280
# 4  694f72e8-d0c5-4ab4-bbc0-5d7fe1d40399  6972b508-8f27-43fc-a30f-473ded4bf974
#
#                                chw_uuid
# 0  a970d423-a8d2-460a-86b8-ea092f9d465f
# 1  815e3451-6ef4-4c84-8731-c0bbfe69bfa3
# 2  cc7f40ce-fcdc-4469-a165-551c527c5d68
# 3  59a3d58c-8875-4b11-a2e1-784befb328f4
# 4  5b1c0410-532a-4473-b8f2-f45f6ff72540
#
# [5 rows x 36 columns]

# %%
## Format Date Types and order records chronologicall
db["reported"] = pd.to_datetime( db["reported"].str[0:19], format="%Y-%m-%d %H:%M:%S") # inplace=True)
db["Year"] = db["reported"].dt.year  
db["Month"] = db["reported"].dt.strftime('%b-%Y') 
db["Day_of_Week"] = db["reported"].dt.weekday_name.str[:3] 

db.sort_values( by='reported', inplace=True)

LAST_UPDATED = db["reported"].max().strftime( '%d-%b-%Y')

print('LAST UPDATED', LAST_UPDATED)
# Out:
# LAST UPDATED 31-May-2018

# %%
display(HTML('<b>Glimpse of the data</b>'))
db.head(3)
# Out:
# <b>Glimpse of the data</b>
#                                         uuid  \
# 299640  F2D4A31F-6D81-710A-A431-361F31F606DC
# 259380  D53D4F7C-6B0B-2944-A5F9-7718D1F88D26
# 146333  1EFE3E24-C206-B8F7-8845-9C56691DD332
#
#                                          chw            reported  \
# 299640  3e863701-9d13-482a-8d56-573245c3b38e 2009-01-01 00:23:26
# 259380  3e863701-9d13-482a-8d56-573245c3b38e 2009-01-01 00:25:36
# 146333  3e863701-9d13-482a-8d56-573245c3b38e 2009-01-01 00:27:44
#
#                                   patient_id patient_date_of_birth  \
# 299640  6EC23524-C580-A2D5-93D8-A1E7652664D2            2005-12-06
# 259380  00D16DEE-B5B6-70E5-A3A1-A384D23411A6            2004-12-02
# 146333  115490F3-DAFA-4D3E-A5C6-037ED663AC11            2011-06-02
#
#         patient_age_in_years  patient_age_in_months patient_coughs  \
# 299640                     3                     36             no
# 259380                     4                     48            yes
# 146333                    -2                    -29            NaN
#
#        patient_diarrhea patient_fever     ...     lat lng  \
# 299640               no           yes     ...     NaN NaN
# 259380               no            no     ...     NaN NaN
# 146333              NaN           NaN     ...     NaN NaN
#
#                              branch_uuid branch_name  \
# 299640  18ba22fb07334baa30fe0e81f9d7e2fc      Malava
# 259380  18ba22fb07334baa30fe0e81f9d7e2fc      Malava
# 146333  18ba22fb07334baa30fe0e81f9d7e2fc      Malava
#
#                              supervisor_uuid  \
# 299640  efbab34c-b531-4181-b770-bd5140434da6
# 259380  efbab34c-b531-4181-b770-bd5140434da6
# 146333  efbab34c-b531-4181-b770-bd5140434da6
#
#                                chw_area_uuid  \
# 299640  efdfdbba-0bcf-4d26-abe3-067b5b854f71
# 259380  efdfdbba-0bcf-4d26-abe3-067b5b854f71
# 146333  efdfdbba-0bcf-4d26-abe3-067b5b854f71
#
#                                     chw_uuid  Year     Month Day_of_Week
# 299640  3e863701-9d13-482a-8d56-573245c3b38e  2009  Jan-2009         Thu
# 259380  3e863701-9d13-482a-8d56-573245c3b38e  2009  Jan-2009         Thu
# 146333  3e863701-9d13-482a-8d56-573245c3b38e  2009  Jan-2009         Thu
#
# [3 rows x 39 columns]

# %% [markdown]
# # Assessment Numbers

# %%
plotObject(20, 7) 
sns.countplot( data=db, x="Month" );

# %%
plotObject(20, 7) 
sns.countplot( data=db, x="branch_name", order=db["branch_name"].value_counts().index );
