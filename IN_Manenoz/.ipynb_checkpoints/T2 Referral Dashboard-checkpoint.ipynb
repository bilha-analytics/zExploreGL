# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [raw]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>
#
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# %run "../../xUtilz/utilz_only_loader.ipynb"

# %%
db = pd.read_csv( "../../datasets/LG/IN/181112_Referral_Reasons.csv" )

# %%
db["CHV Name"] = "CHV " +  pd.Series( pd.factorize( db["CHV Name"])[0] + 1).astype( str)
db["Patient Name"] = "Patient " +  pd.Series( pd.factorize( db["Patient Name"])[0] + 1).astype( str)
db.drop( "CHV Phone", axis=1, inplace=True)

# %%
reasons_groupz = { 
    "Neonates" : [ "months", "umbilical", "umbllical"], 
    "Pregnancy" : ["delivery"], 
    "U5 Danger Signs" : [ "Danger", "Diarrhoea", "Diarrhea", "Dairrhea", "Coughing", "Cough", "Fever","Pneumonia", "Pnuemonia",
                        "Pheumonia", ],
    "HIVST" : ["reactive", "partner", "intimate"], 
    "Unsupported Cases" : []
}

db["Category Referral Reason"] = db["Referral Reason"].apply( lambda x: searchString(x, reasons_groupz) ) 

var_bucket_reasons =  "Category Referral Reason"
var_all_reasons = "All"
var_Unsupported = "Unsupported Cases"
var_HIVST = "HIVST"
var_Display_Colz = ["Date of referral", "CHV Name", "Patient Name" ,"Referral Reason", "Reason for Referral"]

# %%
# 1. set Date of referral to a datetime type 
db["Date of referral"] = pd.to_datetime( db["Date of referral"], format="%d-%b-%y") # inplace=True)

# 2. Extract Month and year categories 
db["Year"] = db["Date of referral"].dt.year 
db["Month"] = db["Date of referral"].dt.strftime('%b-%y') 
db["Day_of_Week"] = db["Date of referral"].dt.weekday_name.str[:3] 

db.sort_values( by='Date of referral', inplace=True)

LAST_UPDATED = db["Date of referral"].max().strftime( '%d-%b-%Y')

db.head().T
# Out:
#                                            0                    14  \
# Date of referral          2018-08-09 00:00:00  2018-08-20 00:00:00
# CHV Name                                CHV 1               CHV 10
# Patient Name                        Patient 1           Patient 14
# Referral Reason               testing testing            Kuchomeka
# Category Referral Reason    Unsupported Cases    Unsupported Cases
# Year                                     2018                 2018
# Month                                  Aug-18               Aug-18
# Day_of_Week                               Thu                  Mon
#
#                                              29                            50  \
# Date of referral            2018-08-23 00:00:00           2018-08-23 00:00:00
# CHV Name                                  CHV 3                        CHV 11
# Patient Name                         Patient 29                    Patient 49
# Referral Reason           Diarrhoea for 3 days,  Itching at his private parts
# Category Referral Reason        U5 Danger Signs             Unsupported Cases
# Year                                       2018                          2018
# Month                                    Aug-18                        Aug-18
# Day_of_Week                                 Thu                           Thu
#
#                                               40
# Date of referral             2018-08-23 00:00:00
# CHV Name                                   CHV 3
# Patient Name                          Patient 40
# Referral Reason           Stomachhach $ dairrhea
# Category Referral Reason         U5 Danger Signs
# Year                                        2018
# Month                                     Aug-18
# Day_of_Week                                  Thu

# %%
## Graphics updating methods

def getFilteredDataset(key):
    df = db
    if( key == var_all_reasons ):
        return df
    else:
        return df[ df['Category Referral Reason'] == key ] 
    

## g1r1 = bar plot referral reasons
def update_g1r1(change):
    key = change['new']
    df = getFilteredDataset(key)
    print( key)
    print( df.head() )
    
    ## Count of reasons for referral based on the broad categories
    plotObject()
    ax = sns.countplot( data=df, x=var_bucket_reasons, order=db[var_bucket_reasons].value_counts().index )

    # set % 
    total = len( db[var_bucket_reasons])
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 1,
                '{:1.0f} %'.format(height/total*100),
                ha="center") 

    plt.title('Reasons for Referral as at %s'% LAST_UPDATED ) ;
    


def getGraphPlaceholder():
    return GraphWidget( 'https://plot.ly/~kevintest/1192/' )

# %%
## Components
## 1. Filter 
reason_filter = widgets.Dropdown(
    options = [var_all_reasons] + db['Category Referral Reason'].unique().tolist(),
    value = var_all_reasons,
    description = 'Referral Reasons Filter',
    style = {'description_width': 'initial'}
)

## 2. container/div for filters
header = widgets.HBox(
    children = [ reason_filter]
)

## 3. Graphs

g1r1 = getGraphPlaceholder()
g2r1 = getGraphPlaceholder()
g3r1 = getGraphPlaceholder()
g1r2 = getGraphPlaceholder()
g2r2 = getGraphPlaceholder()
g3r2 = getGraphPlaceholder()


## 4. container div for graphs
row1 = widgets.HBox( children = [g1r1, g2r1, g3r1] )
row2 = widgets.HBox( children = [g1r2, g2r2, g3r2] )
body = widgets.VBox(
    children = [ row1, row2]
)

## 5. footer
footer = widgets.HBox()

## 6. All together
page = widgets.VBox(
    children = [ header, body, footer]
)


## call backs
reason_filter.observe( update_g1r1, names='value')

display( page)
# Out:
# A Jupyter Widget

# %%
# ?widgets.Box

# %%
from ipywidgets import interact
from matplotlib.dates import DateFormatter, WeekdayLocator, MO


options_list = [ var_all_reasons] + db[var_bucket_reasons].unique().tolist()
#print( options_list )

### plot them
def plot_bar_reasons(df, t):
    ax = sns.countplot( data=df, x=var_bucket_reasons , order=df[var_bucket_reasons].value_counts().index) 
    # set % 
    total = len( df)
    for p in ax.patches:
        height = p.get_height()
        if not( pd.isnull(height) ):
            ax.text(p.get_x()+p.get_width()/2.,
                height + 1,
                '{:1.0f} %'.format(height/total*100),
                ha="center") 

    ax.set_title( t )
    return ax


def plot_bar_timing(df, t):
    ax = sns.countplot( data=df, x="Day_of_Week", order=["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"] )
    # set % 
    total = len( df )
    for p in ax.patches:
        height = p.get_height()
        if not( pd.isnull(height) ): 
            ax.text(p.get_x()+p.get_width()/2.,
                height + 0.1,
                '{:1.0f} %'.format(height/total*100),
                ha="center") 

    ax.set_title( t ) ; 
    return ax

def plot_word_cloud( df, t ):
    stop_words = STOPWORDS.union( ["CHV", "referral" ] )
    ## Translating Swahili to Eng 
    plt.imshow( WordCloud( 
        background_color="white", 
        max_font_size=50, 
        max_words=200, 
        stopwords=stop_words,
    ).generate( " ".join( df["Referral Reason"].fillna('No_Input') ) ) , 
               interpolation='bilinear'  )
    plt.axis( "off" )
    plt.title( t )
    
def plot_hivst_reasons(df, t):
    ax = sns.countplot( data=df, x="Referral Reason" ) 
    # set % 
    total = len( df )
    for p in ax.patches:
        height = p.get_height()
        if not( pd.isnull(height) ):        
            ax.text(p.get_x()+p.get_width()/2.,
                height + 0.1,
                '{:1.0f} %'.format(height/total*100),
                ha="center") 

    ax.set_title( t ) ;  
    return ax

def plot_timeline( df, t):
    myFmt = DateFormatter("%d-%b") 
    
    #ax = sns.countplot( data=df, x="Date of referral" ) 
    ax = df['Date of referral'].value_counts().sort_index().plot.line()
    ax.set_title( t )  
    ax.xaxis_date( )
    ax.xaxis.set_minor_locator(WeekdayLocator(byweekday=MO)) ## intended 
    ax.xaxis.set_major_locator( WeekdayLocator(byweekday=MO, interval=1) ) ## only label at every 4th week 
    #ax.xaxis.set_major_formatter( DateFormatter('%H:%M:') )
    ax.xaxis.set_major_formatter( myFmt)
    return ax


@interact( group_by=options_list )
def plot_by( group_by): 
    if( group_by == var_all_reasons):
        df = db
    else:
        df = db[ db[var_bucket_reasons] == group_by ] 
    
    title = '%s Reasons - %s'% (group_by, LAST_UPDATED )
    title_all = '%s Reasons - %s'% (var_all_reasons, LAST_UPDATED )
    title_unsupported = '%s Reasons - %s'% (var_Unsupported, LAST_UPDATED )
    title_HIVST = '%s Reasons - %s'% (var_HIVST, LAST_UPDATED )
    title_timing = 'Timing: %s Referrals - %s' % (group_by, LAST_UPDATED )

    #f, a = plt.subplots( nrows=2, ncols=3, figsize=(20,15) )

    plt.figure(figsize=(20,15))
    grid = plt.GridSpec( 3, 3, wspace=0.4, hspace=0.3)

    plt.subplot( grid[0,0] )
    plot_bar_reasons(db, title_all )

    plt.subplot( grid[0,1] )
    plot_bar_timing( df, title_timing)

    plt.subplot( grid[0,2] )
    plot_hivst_reasons( db[ db[var_bucket_reasons] == var_HIVST], title_HIVST )

    ## unsupported cases only
    plt.subplot( grid[1,0] )
    plot_word_cloud( db[ (db[var_bucket_reasons]!= var_HIVST) & (db[var_bucket_reasons] == var_Unsupported)] , title_unsupported)

    ## word cloud all cases - no HIVST by default b/c not user entered 
    plt.subplot( grid[1,1] )
    plot_word_cloud( df if group_by == var_HIVST else df[df[var_bucket_reasons]!=var_HIVST], "Referral Reasons - "+group_by)
    #plot_word_cloud(db, 'Referral Reasons')

    ## timeline 
    plt.subplot( grid[2,0:] )
    plot_timeline( df, title_all)

    plt.tight_layout()
# Out:
# A Jupyter Widget

# %%
db[ db[var_bucket_reasons] == var_HIVST]
# Out:
#     Date of referral CHV Name Patient Name  \
# 75        2018-10-25   CHV 23   Patient 71
# 103       2018-10-25   CHV 13   Patient 94
# 30        2018-10-26   CHV 15   Patient 30
# 46        2018-10-28   CHV 16   Patient 45
# 96        2018-10-28   CHV 16   Patient 88
# 19        2018-10-28   CHV 13   Patient 19
# 73        2018-10-29   CHV 13   Patient 69
# 71        2018-10-29   CHV 15   Patient 67
# 58        2018-10-29   CHV 13   Patient 56
# 120       2018-10-29   CHV 13  Patient 107
# 42        2018-10-30   CHV 14   Patient 42
# 83        2018-10-30   CHV 14   Patient 79
# 21        2018-10-30   CHV 14   Patient 21
# 25        2018-11-01   CHV 14   Patient 25
# 125       2018-11-03    CHV 1  Patient 112
# 132       2018-11-05   CHV 10  Patient 117
# 38        2018-11-05   CHV 10   Patient 38
# 53        2018-11-07   CHV 18   Patient 52
# 121       2018-11-10   CHV 25  Patient 108
#
#                                        Referral Reason  \
# 75                      Intimate partner violence case
# 103             CHV referral: reactive or non-disclose
# 30              CHV referral: reactive or non-disclose
# 46              CHV referral: reactive or non-disclose
# 96              CHV referral: reactive or non-disclose
# 19              CHV referral: reactive or non-disclose
# 73              CHV referral: reactive or non-disclose
# 71              CHV referral: reactive or non-disclose
# 58              CHV referral: reactive or non-disclose
# 120             CHV referral: reactive or non-disclose
# 42              CHV referral: reactive or non-disclose
# 83              CHV referral: reactive or non-disclose
# 21              CHV referral: reactive or non-disclose
# 25              CHV referral: reactive or non-disclose
# 125                     Intimate partner violence case
# 132             CHV referral: reactive or non-disclose
# 38                      Intimate partner violence case
# 53              CHV referral: reactive or non-disclose
# 121  CHV referral: reactive or non-discloseInvalid ...
#
#     Category Referral Reason  Year   Month Day_of_Week
# 75                     HIVST  2018  Oct-18         Thu
# 103                    HIVST  2018  Oct-18         Thu
# 30                     HIVST  2018  Oct-18         Fri
# 46                     HIVST  2018  Oct-18         Sun
# 96                     HIVST  2018  Oct-18         Sun
# 19                     HIVST  2018  Oct-18         Sun
# 73                     HIVST  2018  Oct-18         Mon
# 71                     HIVST  2018  Oct-18         Mon
# 58                     HIVST  2018  Oct-18         Mon
# 120                    HIVST  2018  Oct-18         Mon
# 42                     HIVST  2018  Oct-18         Tue
# 83                     HIVST  2018  Oct-18         Tue
# 21                     HIVST  2018  Oct-18         Tue
# 25                     HIVST  2018  Nov-18         Thu
# 125                    HIVST  2018  Nov-18         Sat
# 132                    HIVST  2018  Nov-18         Mon
# 38                     HIVST  2018  Nov-18         Mon
# 53                     HIVST  2018  Nov-18         Wed
# 121                    HIVST  2018  Nov-18         Sat
