# %% [raw]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
UTILZ_DIR = r"C:\Users\BILHA\Google Drive\xRepos\xUtilz"

## load envz
#%run "%s\envz_only_loader.ipynb"%UTILZ_DIR
# %run "C:\Users\BILHA\Google Drive\xRepos\xUtilz\envz_only_loader.ipynb"

## load utilz
# %run "C:\Users\BILHA\Google Drive\xRepos\xUtilz\utilz_only_loader.ipynb"

# %% [markdown]
# \begin{definition}\label{def:}
#
# \end{definition}

# %%
## load dataset
DATA_DIR = r"C:\Users\BILHA\Google Drive\xRepos\datasets\LG\Data Dumps"
db = pd.read_csv( r"%s\Assessments.csv"%DATA_DIR )

# %%
db.info()

print("\nMissing Values")
checkMissing(db)

db.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391109 entries, 0 to 391108
# Data columns (total 36 columns):
# uuid                     391109 non-null object
# chw                      391109 non-null object
# reported                 391109 non-null object
# patient_id               391109 non-null object
# patient_date_of_birth    391073 non-null object
# patient_age_in_years     391109 non-null int64
# patient_age_in_months    391109 non-null int64
# patient_coughs           383128 non-null object
# patient_diarrhea         383127 non-null object
# patient_fever            383127 non-null object
# danger_signs             31729 non-null object
# diagnosis_cough          155526 non-null object
# diagnosis_diarrhea       39911 non-null object
# diagnosis_fever          255207 non-null object
# coughing_duration        155526 non-null float64
# diarrhea_duration        39911 non-null float64
# fever_duration           252306 non-null float64
# ...

# %%
print("\n\n5. Sample Structure")
sampleStructure( db )
# Out:
# 5. Sample Structure
#                                                     CHP  Phone Number  \
# mean                                                NaN  2.547525e+11
# sum   Mary Asigo LumwagiNancy AchesaWilliam IjendiRo...  3.803455e+14
#
#                                                  CHP ID  Pregnancy  \
# mean                                                NaN        0.3
# sum   042d8caa-5ff0-4b35-8aac-80e7015a76e931ac0ec5-b...      408.0
#
#       PNC Visit Rate  PNC Visit Missed - #  Total U1 Assessments  \
# mean             0.1                   0.1                   0.8
# sum            192.3                 220.0                1216.0
#
#       Total U1 Treatments  Total U5 Assessments  Total U5 Treatments  \
# mean                  0.3                   3.6                  1.7
# sum                 497.0                5393.0               2531.0
#
#               ...            On Time Referral f/u Treatment U5  Missed Visits  \
# ...

# %%
print("\n\n 6. Describe")
#summarizer( db, colz=["Total Population", "Pct Female"])
summarizer( db)
# Out:
#  6. Describe
#                   CHP  Phone Number                                CHP ID  \
# count            1493  1.493000e+03                                  1493
# unique           1493           NaN                                  1493
# top     Francis Olagi           NaN  74bdcbac-26de-4d5b-8228-90bbe6abede4
# freq                1           NaN                                     1
# mean              NaN  2.547525e+11                                   NaN
# std               NaN  6.268657e+07                                   NaN
# min               NaN  2.547020e+11                                   NaN
# 20%               NaN  2.547160e+11                                   NaN
# 40%               NaN  2.547260e+11                                   NaN
# 50%               NaN  2.547400e+11                                   NaN
# 60%               NaN  2.547430e+11                                   NaN
# ...

# %%
print("\n\n Plotting Distributions")
#plotDistz( db , colz=["Males", "Females"]) #, grp="Age Group", stk=False)
plotDistz( db );
plotBoxz( db );
# Out:
#  Plotting Distributions

# %%
print( "\n\n 7. Frequencies")
frequenciez( db, colz=[ "mRDT Used"] );  #, grp="Age Group", flipaxis=True )

#pd.crosstab( dataset.Females, dataset["Age Group"], margins=True).apply( lambda x: x/len(dataset)).round(4)*100
#fqTablez( dataset, "AgrGroup", colz=["Females", "Males"])
# Out:
#  7. Frequencies
